# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import openpyxl
import os

# %%
df1=pd.read_excel(
     os.path.join("Data_Train.xlsx"),
     engine='openpyxl',
)

# %%
df1
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df1['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 27h 55m      1
# 33h 45m      1
# 32h 20m      1
# 47h 40m      1
# 41h 20m      1
# Name: Duration, Length: 368, dtype: int64

# %%
df1['Duration'].dtypes
# Out:
# dtype('O')

# %%
#checking null values
df1.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#since data is huge so we can let go of 2 entries
df1.dropna(inplace=True)
df1.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df1['Date_of_Journey']=pd.to_datetime(df1['Date_of_Journey'])

# %%
df1['month']=df1['Date_of_Journey'].dt.month
df1['is_week_end']=(df1['Date_of_Journey'].dt.weekday>4)
df1['is_week_end']=df1['is_week_end'].astype(int)

# %%
df1.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df1
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  month  \
# ...

# %%
df1['dep_hr']=pd.to_datetime(df1['Dep_Time']).dt.hour
df1['arrival_hr']=pd.to_datetime(df1['Arrival_Time']).dt.hour

# %%
df1['dep_min']=pd.to_datetime(df1['Dep_Time']).dt.minute
df1['arrival_min']=pd.to_datetime(df1['Arrival_Time']).dt.minute

# %%
df1=df1.drop(['Arrival_Time','Dep_Time'],axis=1)

# %%
len(df1)
# Out:
# 10682

# %%
duration=list(df1['Duration'])
duration
# Out:
# ['2h 50m',
#  '7h 25m',
#  '19h',
#  '5h 25m',
#  '4h 45m',
#  '2h 25m',
#  '15h 30m',
#  '21h 5m',
#  '25h 30m',
#  '7h 50m',
#  '13h 15m',
#  '2h 35m',
#  '2h 15m',
#  '12h 10m',
#  '2h 35m',
#  '26h 35m',
#  '4h 30m',
#  '22h 35m',
#  '23h',
#  '20h 35m',
#  '5h 10m',
#  '15h 20m',
#  '2h 50m',
#  '2h 55m',
#  '13h 20m',
#  '15h 10m',
#  '5h 45m',
#  '5h 55m',
#  '2h 50m',
#  '2h 15m',
#  '2h 15m',
#  '13h 25m',
#  '2h 50m',
#  '22h',
#  '5h 30m',
#  '10h 25m',
#  '5h 15m',
#  '2h 30m',
#  '6h 15m',
#  '11h 55m',
#  '11h 5m',
#  '8h 30m',
#  '22h 5m',
#  '2h 45m',
#  '12h',
#  '2h 50m',
#  '2h 50m',
#  '2h 15m',
#  '16h 5m',
#  '19h 55m',
#  '3h 15m',
#  '25h 20m',
#  '2h 50m',
#  '3h',
#  '2h 50m',
#  '16h 15m',
#  '15h 5m',
#  '2h 15m',
#  '6h 30m',
#  '25h 5m',
#  '12h 25m',
#  '27h 20m',
#  '10h 15m',
#  '10h 30m',
#  '2h 15m',
#  '10h 25m',
#  '2h 50m',
#  '1h 30m',
#  '13h 20m',
#  '2h 15m',
#  '1h 25m',
#  '26h 30m',
#  '7h 20m',
#  '13h 30m',
#  '5h',
#  '2h 45m',
# ...

# %%
for i in range(len(duration)):
    x=duration[i].split()
    if len(x)!=2:
        if 'h' in duration[i]:
            duration[i]=duration[i].strip()+' 0m'
        else:
            duration[i]='0h '+duration[i]
duration_hrs=[]
duration_mins=[]
for j in range(len(duration)):
    duration_hrs.append(int(duration[j].split(sep='h')[0]))
    duration_mins.append(int(duration[j].split(sep='m')[0].split()[-1]))

# %%
df1['duration_hrs']=duration_hrs
df1['duration_mins']=duration_mins

# %%
df1.drop('Duration',axis=1,inplace=True)

# %%
df1['Additional_Info'].value_counts()
# Out:
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
df1['Additional_Info'].replace({'No Info':'No Info'},inplace=True)
df1['Additional_Info'].value_counts()
# Out:
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# # adding some features from additional info

# %% [markdown]
# ## meal_not_provided_feature

# %%
df1['meal_not_provided']=df1['Additional_Info']=='In-flight meal not included'

# %%
df1['meal_not_provided']=df1['meal_not_provided'].astype(int)

# %% [markdown]
# ## no-baggage included feature

# %%
df1['no-baggage_included']=df1['Additional_Info']=='No check-in baggage included'
df1['no-baggage_included']=df1['no-baggage_included'].astype(int)

# %%
df1.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  month  is_week_end  dep_hr  arrival_hr  dep_min  \
# 0         No info   3897      3            1      22           1       20
# 1         No info   7662      1            1       5          13       50
# 2         No info  13882      9            0       9           4       25
# 3         No info   6218     12            0      18          23        5
# 4         No info  13302      1            0      16          21       50
#
#    arrival_min  duration_hrs  duration_mins  meal_not_provided  \
# ...

# %% [markdown]
# # total stops feature

# %%
df1['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
df1.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

# %%
df1.head()
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL            0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR            2
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK            2
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR            1
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL            1
#
#   Additional_Info  Price  month  is_week_end  dep_hr  arrival_hr  dep_min  \
# 0         No info   3897      3            1      22           1       20
# 1         No info   7662      1            1       5          13       50
# 2         No info  13882      9            0       9           4       25
# 3         No info   6218     12            0      18          23        5
# 4         No info  13302      1            0      16          21       50
#
#    arrival_min  duration_hrs  duration_mins  meal_not_provided  \
# ...

# %% [markdown]
# # dropping route and additional info

# %%
df1.drop(['Route','Additional_Info'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Price', 'month',
#        'is_week_end', 'dep_hr', 'arrival_hr', 'dep_min', 'arrival_min',
#        'duration_hrs', 'duration_mins', 'meal_not_provided',
#        'no-baggage_included'],
#       dtype='object')

# %%
df1=df1[['Airline', 'Source', 'Destination', 'Total_Stops', 'month',
       'is_week_end', 'dep_hr', 'arrival_hr', 'dep_min', 'arrival_min',
       'duration_hrs', 'duration_mins', 'meal_not_provided',
       'no-baggage_included', 'Price']]

# %%
df2=pd.get_dummies(df1,drop_first=True)
df2.columns
# Out:
# Index(['Total_Stops', 'month', 'is_week_end', 'dep_hr', 'arrival_hr',
#        'dep_min', 'arrival_min', 'duration_hrs', 'duration_mins',
#        'meal_not_provided', 'no-baggage_included', 'Price',
#        'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
#        'Airline_Jet Airways', 'Airline_Jet Airways Business',
#        'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
#        'Destination_Kolkata', 'Destination_New Delhi'],
#       dtype='object')

# %%
df2=df2[['Total_Stops', 'month', 'is_week_end', 'dep_hr', 'arrival_hr',
       'dep_min', 'arrival_min', 'duration_hrs', 'duration_mins',
       'meal_not_provided', 'no-baggage_included',
       'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
       'Airline_Jet Airways', 'Airline_Jet Airways Business',
       'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
       'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
       'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
       'Destination_Kolkata', 'Destination_New Delhi', 'Price']]

# %%
df2
# Out:
#        Total_Stops  month  is_week_end  dep_hr  arrival_hr  dep_min  \
# 0                0      3            1      22           1       20
# 1                2      1            1       5          13       50
# 2                2      9            0       9           4       25
# 3                1     12            0      18          23        5
# 4                1      1            0      16          21       50
# ...            ...    ...          ...     ...         ...      ...
# 10678            0      9            0      19          22       55
# 10679            0      4            1      20          23       45
# 10680            0      4            1       8          11       20
# 10681            0      1            0      11          14       30
# 10682            2      9            0      10          19       55
#
#        arrival_min  duration_hrs  duration_mins  meal_not_provided  ...  \
# 0               10             2             50                  0  ...
# ...

# %% [markdown]
# # similarly working with test data

# %%
df3=pd.read_excel(
     os.path.join("Test_set.xlsx"),
     engine='openpyxl',
)

# %%
df3
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df3.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# # just do all the things we have done with our train setm

# %%
df3['Date_of_Journey']=pd.to_datetime(df3['Date_of_Journey'])
df3['month']=df3['Date_of_Journey'].dt.month
df3['is_week_end']=(df3['Date_of_Journey'].dt.weekday>4)
df3['is_week_end']=df3['is_week_end'].astype(int)

# %%
df3.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df3['dep_hr']=pd.to_datetime(df3['Dep_Time']).dt.hour
df3['arrival_hr']=pd.to_datetime(df3['Arrival_Time']).dt.hour

df3['dep_min']=pd.to_datetime(df3['Dep_Time']).dt.minute
df3['arrival_min']=pd.to_datetime(df3['Arrival_Time']).dt.minute

df3=df3.drop(['Arrival_Time','Dep_Time'],axis=1)

# %%
duration1=list(df3['Duration'])
duration1

for i in range(len(duration1)):
    x=duration1[i].split()
    if len(x)!=2:
        if 'h' in duration1[i]:
            duration1[i]=duration1[i].strip()+' 0m'
        else:
            duration1[i]='0h '+duration1[i]
duration1_hrs=[]
duration1_mins=[]
for j in range(len(duration1)):
    duration1_hrs.append(int(duration1[j].split(sep='h')[0]))
    duration1_mins.append(int(duration1[j].split(sep='m')[0].split()[-1]))
    
df3['duration_hrs']=duration1_hrs
df3['duration_mins']=duration1_mins

df3.drop('Duration',axis=1,inplace=True)

df3['Additional_Info'].value_counts()
# Out:
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Change airports                    1
# 1 Long layover                     1
# Business class                     1
# Name: Additional_Info, dtype: int64

# %%
df3['meal_not_provided']=df3['Additional_Info']=='In-flight meal not included'
df3['meal_not_provided']=df3['meal_not_provided'].astype(int)

df3['no-baggage_included']=df3['Additional_Info']=='No check-in baggage included'
df3['no-baggage_included']=df3['no-baggage_included'].astype(int)

df3.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

df3.drop(['Route','Additional_Info'],axis=1,inplace=True)

df4=pd.get_dummies(df3,drop_first=True)

#adding this feature in test as it is present in training data 
df4['Airline_Trujet']=0
df4
# Out:
#       Total_Stops  month  is_week_end  dep_hr  arrival_hr  dep_min  \
# 0               1      6            0      17           4       30
# 1               1     12            0       6          10       20
# 2               1      5            0      19          19       15
# 3               1      5            0       8          21        0
# 4               0      6            0      23           2       55
# ...           ...    ...          ...     ...         ...      ...
# 2666            1      6            0      20          20       30
# 2667            0      3            0      14          16       20
# 2668            1      6            0      21           4       50
# 2669            1      6            0       4          19        0
# 2670            1      6            1       4          19       55
#
#       arrival_min  duration_hrs  duration_mins  meal_not_provided  ...  \
# 0              25            10             55                  0  ...
# ...

# %%
df4=df4[['Total_Stops', 'month', 'is_week_end', 'dep_hr', 'arrival_hr',
       'dep_min', 'arrival_min', 'duration_hrs', 'duration_mins',
       'meal_not_provided', 'no-baggage_included',
       'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
       'Airline_Jet Airways', 'Airline_Jet Airways Business',
       'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
       'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
       'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
       'Destination_Kolkata', 'Destination_New Delhi']]

# %% [markdown]
# # now making an ml model on training data after seprating training data

# %%
x=df2.drop('Price',axis=1)
y=df2['Price']

# %%
from sklearn.model_selection import train_test_split as tts
train_x,test_x,train_y,test_y=tts(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### checking correlation between features

# %%
#we can see no correlation is there in between features
plt.figure(figsize=(18,18))
sns.heatmap(df1.corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
import xgboost
from xgboost import XGBRegressor

# %%
# Out:
# 10507    14781
# 7705      5636
# 7700      3597
# 1437     16757
# 8884      4804
#          ...
# 6391      3943
# 9273      4804
# 6199      8971
# 10037     9663
# 8970      3873
# Name: Price, Length: 2137, dtype: int64

# %%
xg=XGBRegressor()

# %%
xg
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
xg.fit(train_x,train_y)
xg.feature_importances_
# Out:
# array([2.6136149e-02, 1.4093471e-02, 5.8439770e-03, 5.7989024e-03,
#        6.3311155e-03, 6.1176778e-03, 6.6137677e-03, 1.4953691e-01,
#        5.5801105e-03, 8.3069243e-02, 1.4902103e-03, 9.5938388e-03,
#        1.5323392e-02, 2.4750074e-02, 1.5917452e-01, 2.7596194e-01,
#        4.0242497e-02, 6.3781491e-03, 1.9348159e-02, 2.1723144e-04,
#        6.2006847e-03, 5.4390472e-04, 7.3050959e-03, 1.7071262e-02,
#        2.8513785e-02, 1.8196905e-02, 0.0000000e+00, 4.3602283e-03,
#        0.0000000e+00, 0.0000000e+00, 5.6206692e-02], dtype=float32)

# %%
plt.figure(figsize=(12,10))
fe=pd.Series(xg.feature_importances_,index=x.columns)
fe.nlargest(31).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[50,100,200,300,400,500,600,700],'max_depth':[2,5,10,15,20]}
rs_cv=GridSearchCV(estimator=xg ,param_grid=parameters,scoring='neg_mean_squared_error',cv=5,verbose=2,n_jobs=-1)

# %%
train_x.drop(['Destination_Kolkata','Destination_Hyderabad','Destination_Cochin','Airline_Trujet','Airline_Vistara Premium economy'],axis=1,inplace=True)
test_x.drop(['Destination_Kolkata','Destination_Hyderabad','Destination_Cochin','Airline_Trujet','Airline_Vistara Premium economy'],axis=1,inplace=True)
# Out:
# c:\users\91811\.conda\envs\myenv\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
xg=XGBRegressor()

# %%
rs_cv.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0, gpu_id=-1,
#                                     importance_type='gain',
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_delta_step=0,
#                                     max_depth=6, min_child_weight=1,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=100, n_jobs=12,
#                                     num_parallel_tree=1, random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=1,
# ...

# %%
rs_cv.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 100}

# %%
prediction1=rs_cv.predict(test_x)

# %%
rs_cv.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0, gpu_id=-1,
#                                     importance_type='gain',
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_delta_step=0,
#                                     max_depth=6, min_child_weight=1,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=100, n_jobs=12,
#                                     num_parallel_tree=1, random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=1,
# ...

# %%
#plot graph of feature importances for better visualization

plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
print('r2_score:',metrics.r2_score(test_y, prediction1))
print('MAE:', metrics.mean_absolute_error(test_y, prediction1))
print('MSE:', metrics.mean_squared_error(test_y, prediction1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(test_y, prediction1)))
# Out:
# r2_score: 0.8283222745786892
# MAE: 1060.8936074113644
# MSE: 4028104.509745376
# RMSE: 2007.013828987079

# %%
import pickle
# open a file, where you ant to store the data
file = open('flight_prediction.pkl', 'wb')

# dump information to that file
pickle.dump(rs_cv, file)

# %%
model = open('rs_cv.pkl','rb')
xgb = pickle.load(model)

# %%
#predicting on given test data
y_prediction = forest.predict(df4)

# %%
#this is prediction made by us for kaggle project
y_prediction
# Out:
# array([14596.944,  4742.534, 12111.071, ..., 14878.989,  8860.561,
#         7323.612], dtype=float32)
